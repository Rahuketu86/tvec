# %%
#hide
from tvec.core import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
#hide
# %matplotlib inline

# %% [markdown]
# # Time2vec encoding
#
# > This notebook examines keras implementation of time2vec paper

# %% [markdown]
# This notebook examines time2vec encoding as presented by \cite{kazemi2019time2vec}. Core idea  of the paper is to develop *develop a general-purpose model-agnostic representation for time that can be potentially used in any architecture*. Lets examine with recommended dataset

# %% [markdown]
# ## Read Dataset

# %%
ds_url = "https://raw.githubusercontent.com/lbcommer/venezia-high-waters/master/output/venezia.csv"

# %%
df = pd.read_csv(ds_url,parse_dates=['datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289272 entries, 0 to 289271
# Data columns (total 2 columns):
# datetime    289272 non-null datetime64[ns]
# level       289272 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.4 MB

# %%
df = df.sort_values('datetime', ascending=True)

# plt.plot(df['datetime'], df['level'])

df.plot(x='datetime', y='level', figsize=(15, 12))

# %% [markdown]
# ## Data utils for LSTM
